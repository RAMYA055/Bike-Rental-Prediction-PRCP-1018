# %%
# !git add .

# %%
# !git commit -m'I completed feature engineering'
# Out:
# error: pathspec 'completed' did not match any file(s) known to git
# error: pathspec 'feature' did not match any file(s) known to git
# error: pathspec 'engineering'' did not match any file(s) known to git

# %%
# !git push
# Out:
# Everything up-to-date
